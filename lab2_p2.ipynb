# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams.update({'font.size': 16})

df = pd.read_csv("experiment_lab2p2.csv")
df
# Out:
#    exp  media_sa  media_sb
# 0    0  0.277219  0.125424
# 1    1  0.213971  0.187600
# 2    2  0.243130  0.156083
# 3    3  0.204323  0.198320
# 4    4  0.211398  0.190602
# 5    5  0.246774  0.154154
# 6    6  0.279792  0.121994
# 7    7  0.180525  0.220832
# 8    8  0.228765  0.169162
# 9    9  0.218474  0.183312

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['media_sa'], bins=10, color='darkblue', label='Servidor A')
plt.hist(df['media_sb'], bins=10, color='orange', label='Servidor B')

plt.xlabel("Goodput (Mbps)")
plt.ylabel("Frequência")
plt.title("Goodput (Mbps)")
plt.legend()
plt.show()

# %%
print(df['media_sa'].mean())
print(df['media_sb'].mean())
# Out:
# 0.2304371
# 0.1707483
